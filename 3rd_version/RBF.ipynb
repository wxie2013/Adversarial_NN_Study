# %% [markdown]
# The following code is to check adversarial attached on different neural networks. The following tutorials or codes have been very useful during the development:
#
#     https://github.com/PetraVidnerova/rbf_keras
#     https://keras.io/layers/writing-your-own-keras-layers/
#     https://nextjournal.com/gkoehler/digit-recognition-with-keras
#     https://fairyonice.github.io/Generate-adversarial-examples-using-TensorFlow.html
#     https://www.anishathalye.com/2017/07/25/synthesizing-adversarial-examples/
#     https://machinelearningmastery.com/handwritten-digit-recognition-using-convolutional-neural-networks-python-keras/

# %%
import tensorflow as tf

import numpy as np

import pandas as pd

import os

import matplotlib.pyplot as plt 
# %matplotlib inline

import gzip
import _pickle as cPickle


import sklearn
from sklearn import datasets
from sklearn import utils
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from sklearn.preprocessing import scale


from IPython import display

from keras.models import Sequential, load_model, Model
from keras.layers.core import Dense
from keras.optimizers import RMSprop
from keras import backend as K
from keras.engine.topology import Layer
from keras.initializers import RandomUniform, Initializer, Orthogonal, Constant
from keras.layers.core import Dense, Dropout, Activation
from keras.utils import np_utils
from keras.datasets import mnist
from keras.layers import Conv2D, Flatten, MaxPooling2D

from tensorflow.python.framework import graph_util
from tensorflow.python.framework import graph_io

import math
import random 
import time
# Out:
# Using TensorFlow backend.

# %%
#_____initializer for RBF
class InitCentersKmean(Initializer):
    """ Initializer for initialization of centers of RBF network
        using K-mean.

    # Arguments
        X: matrix, dataset to choose the centers from (random rows 
          are taken as centers)
    """
    def __init__(self, X):
        self.X = X
        print("_____ initializing center using InitCentersKmean _____")

    def __call__(self, shape, dtype=None):
        # "shape" is the input_shape for "self.add_weigh" down below
        self.center = sklearn.cluster.k_means(self.X, init='random', n_clusters=shape[0], max_iter = 1, n_jobs=-1)
        
        return self.center[0]

#______ the custom RBF layer        
class RBFLayer(Layer):
    """ Layer of Gaussian RBF units. 

    # Example
 
    ```python
        model = Sequential()
        model.add(RBFLayer(10,
                           initializer=InitCentersRandom(X), 
                           betas=1.0,
                           input_shape=(1,)))
        model.add(Dense(1))
    ```
    

    # Arguments
        output_dim: number of hidden units (i.e. number of outputs of the layer)
        initializer: instance of initiliazer to initialize centers
        betas: float, initial value for betas 

    """
   
    def __init__(self, output_dim, betas, initializer, **kwargs):
        self.output_dim = output_dim # dim of the layer's output, i.e. in this case: number of centers in this layer
        self.init_betas = betas 
        self.initializer = initializer 

        super().__init__(**kwargs) #python3 format

    # input shape is the shape from output of last layers. in this case, it's data: [?, 784]
    def build(self, input_shape): 
        self.centers = self.add_weight(name='centers', 
                                       shape=(self.output_dim, input_shape[1]),
                                       initializer=self.initializer,
                                       trainable=True)
        
        self.betas = self.add_weight(name='betas',
                                     shape=(self.output_dim,), 
                                     initializer=Constant(value=self.init_betas),
                                     trainable=True)
        
        super().build(input_shape) #python3
     
    def call(self, x):

        C=K.expand_dims(self.centers) # shape (ncenter, 784, 1) for broadcast
        H = K.transpose(C-K.transpose(x)) # K.transpose(x) shape (784, ?), then this shape: 

        """
        # the following printout is used for debugging purpose
        print("self.centers.shape: ", self.centers.shape)
        print("x.shape", x.shape)
        print("K.transpose(x).shape: ", K.transpose(x).shape)
        print("C.shape: ", C.shape)
        print("H.shape: ", H.shape)
        print("self.betas.shape: ", self.betas.shape)
        print("K.sum(H**2, axis=-2).shape: ", K.sum(H**2, axis=-2).shape)
        print("call return shape: ", K.exp( -self.betas * K.sum(H**2, axis=-2)).shape)
        """
        a = K.exp( -K.sum(H**2, axis=-2)/(2*self.betas*self.betas))
        
        return a
             

    def compute_output_shape(self, input_shape):
        return (input_shape[0], self.output_dim)


    def get_config(self):
        # have to define get_config to be able to use model_from_json
        config = {
            'output_dim': self.output_dim
        }
        #base_config = super(RBFLayer, self).get_config()
        base_config = super().get_config()
        return dict(list(base_config.items()) + list(config.items()))

# %%
#___ load and normalize mnist data 
def load_mnist_data(n_classes):

    (X_train_raw, Y_train_raw), (X_test_raw, Y_test_raw) = mnist.load_data()
    
    #plt.imshow(X_train_raw[0])
    # Normalizing the input data to max=1 helps to speed up the training. 
    # reshape each image to 1D vector for simplicity
    n_train = X_train_raw.shape[0]
    n_test = X_test_raw.shape[0]
    v_len = X_train_raw.shape[1]*X_train_raw.shape[2]    
    
    X_train = X_train_raw.reshape(n_train, v_len)
    X_test = X_test_raw.reshape(n_test, v_len)
    
    # normalizing the data to help with the training. accurancy is lower than sklearn.preprocessing.scale
    """
    max_pixel = np.max(X_train)
    X_train = X_train.astype('float32')
    X_test = X_test.astype('float32')
    X_train /= max_pixel
    X_test /= max_pixel
    """
    #using sklearn.preprocessing.scale, leads to higher accuracy than normalization by max as above
    X_train = scale(X_train)
    X_test = scale(X_test)

    
    #Do it only when the final layers output is, e.g. 10
    # one-hot encoding using keras' numpy-related utilities
    Y_train = np_utils.to_categorical(Y_train_raw, n_classes)
    Y_test = np_utils.to_categorical(Y_test_raw, n_classes)
    
    return X_train_raw, Y_train_raw, X_test_raw, Y_test_raw, X_train, Y_train, X_test, Y_test

# %%
#__ Neural network model
class NN_model():
    def __init__(self, name, X, n_classes, n_center, beta, initializer):
                
        self.model = Sequential()
                    
        if  "RBF" in name: # need to change number of centers in the RBF
            print("++++ using RBF network +++++")
            one_sample_shape = X.shape[-1] # shape for each individual sample

            self.rbflayer = RBFLayer(n_center, beta, 
                                    initializer=initializer(X),
                                    # input_shape is the data shape. The 2nd dim of (one_sample_shape, ) is the number of samples and is treated as ? in keras
                                    input_shape=(one_sample_shape, ), name=name) 

            self.model.add(self.rbflayer)
            self.model.add(Dense(n_classes, name='logits'))
            self.model.add(Activation('softmax'))
        elif name=="dense_1L": 
            print("++++ using 1-hidden layer w/10 neutons dense network +++++")
            self.model.add(Dense(10, input_shape=(784,), name=name))
            self.model.add(Activation('relu'))                            
            #self.model.add(Dropout(0.2))
            self.model.add(Dense(n_classes, name='logits'))
            self.model.add(Activation('softmax'))
        elif name=="dense": 
            print("++++ using 2-hidden layer w/512 neurons dense network +++++")
            self.model.add(Dense(512, input_shape=(784,), name=name))
            self.model.add(Activation('relu'))                            
            #self.model.add(Dropout(0.2))

            self.model.add(Dense(512))
            self.model.add(Activation('relu'))
            #self.model.add(Dropout(0.2))

            self.model.add(Dense(n_classes, name='logits'))
            self.model.add(Activation('softmax'))
        elif name=="CNN_simple": 
            self.model.add(Conv2D(32, (5, 5), input_shape=(28, 28, 1), activation='relu', name=name)) # tf image order: (x, y, channel)
            self.model.add(MaxPooling2D(pool_size=(2, 2)))
            self.model.add(Dropout(0.2))
            self.model.add(Flatten())
            self.model.add(Dense(128, activation='relu'))
            self.model.add(Dense(n_classes, name='logits'))
            self.model.add(Activation('softmax'))
        elif name=="CNN":
            # define the larger model
            self.model.add(Conv2D(16, kernel_size=(3, 3), input_shape=(28, 28, 1), strides=2, activation='relu', name=name))
            self.model.add(Conv2D(32, kernel_size=(3, 3), strides=2, activation='relu'))
            self.model.add(Conv2D(64, kernel_size=(3, 3), strides=2, activation='relu'))
            self.model.add(Flatten()) # flatten the output for the input to dense layer
            self.model.add(Dense(256, activation='relu'))
            self.model.add(Dense(n_classes, name='logits'))
            self.model.add(Activation('softmax'))
        else:
            print("+++++ only option: RBF or dense_1L or dense or CNN_simple or CNN ++++")
            exit()
                             # file and directory for storing weight
        self.weight_dir = 'keras_model_parameter/'
        self.weight_file = self.weight_dir+name+'_weights.h5'
        if not os.path.isdir(self.weight_dir):
            os.mkdir(self.weight_dir)
    
        #self.model.summary()
        self.model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
   
    def outputs(self):
        return self.model.outputs
    
    def inputs(self):
        return self.model.inputs

# %%
#__ daughter class of NN_model, focus on functionality
class NN_mnist(NN_model):
    def __init__ (self, name, n_classes, X, Y, X_raw, Y_raw, X_val, Y_val, n_center = 10, initializer=InitCentersKmean, beta=10):
        self.name = name
        
        self.X_raw = X_raw  # input original data 
        self.Y_raw = Y_raw  # input original label         
        self.X = self.reshape_inputs(X)  # input  data after normalization for mean and variance 
        self.Y = Y  # input label after one_hot conversion
        self.X_val = self.reshape_inputs(X_val) # validation data during the model.fit
        self.Y_val = Y_val # validation label during model.fit
               
        print(self.X.shape, self.X_val.shape, "++++")    
        
        super().__init__(name, X, n_classes, n_center, beta, initializer) # initialize parents class
    
    # everything else is the same except the objects included in this function, in this case, self.X, self.X_raw, self.Y_raw
    def __call__(self, X):
        self.X = self.reshape_inputs(X)
        
        return self.get_logits(), self.get_probs()
    
    ## cnn need inputs (nsample, color, x_pixel, y_pixel), dense net need inputs: (nsample, x_pixel, y_pixel)
    def reshape_inputs(self, X):
        if "CNN" in self.name: # CNN need 4-D array inputs
            if X.ndim == 1:  # single image
                X = X.reshape(1, 28, 28, 1).astype('float32') # cnn need inputs (nsample, x_pixel, y_pixel, color)
            elif X.ndim==2: 
                X = X.reshape(X.shape[0], 28, 28, 1).astype('float32')
        else:  # dense net need 2-D inputs
            if X.ndim == 1: # single image
                X = X.reshape(1, X_train.shape[1]).astype('float32')  # dense net need inputs: (nsample, x_pixel*y_pixel)

        return X
    

    # plot the loss and accuracy of the training as a function of epoch
    def plot_training_history(self):
        fig = plt.figure()
        plt.subplot(2,1,1)
        plt.plot(self.history.history['acc'])
        plt.plot(self.history.history['val_acc'])
        plt.title('model accuracy')
        plt.ylabel('accuracy')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='lower right')

        plt.subplot(2,1,2)
        plt.plot(self.history.history['loss'])
        plt.plot(self.history.history['val_loss'])
        plt.title('model loss')
        plt.ylabel('loss')
        plt.xlabel('epoch')
        plt.legend(['train', 'test'], loc='upper right')

        plt.tight_layout()

    
    # plot images samples
    def plot(self, indices, n_sample, figsize):
        fig, axes = plt.subplots(3,n_sample,figsize=figsize, subplot_kw={'xticks':[], 'yticks':[]}) #subplot_kw option removes ticks in X, Y axes
        for i in range(n_sample):
            index=indices[i]
            
            #  the original image before the normalization (this should be used for adversarial attacks)
            axes[0, i].imshow(self.X_raw[index], cmap='gray', interpolation='none')
            axes[0, i].set_title("True: {}  predict: {}".format(self.Y_raw[index], self.predicted_classes[index]))

            # normalized image. The background become uneven due to the normalization. Looks like already has ADATK
            a = self.X[index].reshape(28, 28)
            axes[1, i].imshow(a, cmap='gray', interpolation='none')

            # 1-D histogram of normalized image
            if "CNN" in self.name:
                axes[2, i].hist(self.X[index].reshape(28*28), bins=20) 
            else:
                axes[2, i].hist(self.X[index],  bins=20) 

        fig.tight_layout()
        fig.subplots_adjust(hspace=0.01)
    

    # plot image samples include original, normalized. Need to be updated to included ada image later.
    def plot_random_sample(self, X, X_raw, Y_raw, which_to_plot, n_sample = 8, figsize=(15,5)):   
        
        self.X = self.reshape_inputs(X)
        self.X_raw = X_raw
        self.Y_raw = Y_raw
        
        # identify the indices of correctly and incorrectly recognized images
        self.identify_correct_incorrect_prediction()
        
        if which_to_plot == "correct":
            print("__correctly identified image _____")
            indices = np.random.choice(self.correct_indices, size=n_sample) # random indices of correctly identifed images 
        elif which_to_plot == "incorrect":
            print("__wrongly identified image _____")
            indices = np.random.choice(self.incorrect_indices, size=n_sample) # random indices of incorrectly identified images in the data
        else:
            print("___ try again on inputs: correct or incorrect ___")

        self.plot(indices, n_sample, figsize)
        
    # evulated the model
    def eval(self):
        loss_and_metrics = self.model.evaluate(self.X, self.Y, verbose=2) # the metric is defined when compiling the model
        print("__Loss:  ", loss_and_metrics[0])
        print("__Accuracy: ", loss_and_metrics[1])
        
    # identify correct or incorrect prediction indices which is used for plotting later
    def identify_correct_incorrect_prediction(self): 
        print("___ calculating the correct and incorrect prediction _____")
        self.predicted_classes = np.argmax(self.model.predict(self.X), axis=-1)
        self.correct_indices = np.nonzero(self.predicted_classes == self.Y_raw)[0]
        self.incorrect_indices = np.nonzero(self.predicted_classes != self.Y_raw)[0]
        print("__complete___")
        
            # run the model, save the weight and plot the training history
    def run(self, batch_size=100, epochs=1, verbose=2):
        self.history = self.model.fit(self.X, self.Y,
                                      batch_size,
                                      epochs,
                                      verbose,
                                      validation_data=(self.X_val, self.Y_val))
        # saving the model
        """
        # loading model has problem this way. it complain RBF layer is not unknow. 
        save_dir = "./results/"
        model_name = 'RBF.h5'
        model_path = os.path.join(save_dir, model_name)
        model.save(model_path)
        print('Saved trained model at %s ' % model_path)
        """
        print("___ saving the model weight____")    
        self.model.save_weights(self.weight_file)
                
        # plot the history of the training 
        self.plot_training_history()
        
    # load the model weight. Currently the can not save the entire model since it compile RBFlayer is not defined
    def load_model(self): 
        if os.path.exists(self.weight_file):
            self.model.load_weights(self.weight_file)
        else:
            print("++++ no model weight file: ", self.weight_file, "can be found ++++")
            exit()


    # get output from a layers. In this case, for logits
    def get_logits(self):

        self.logits_layer_model = Model(inputs=self.model.input, outputs=self.model.get_layer('logits').output)
  
        return self.logits_layer_model.predict(self.X)
    
    # get the probability of each class
    def get_probs(self):
        return self.model.predict(self.X)

# %%
#+++++++++++ input parameters for running the model ++++++++++
model_ID = 6
is_training = True   # training or loading a model
epochs=1

batch_size=100 
verbose=1 # printout information
n_classes = 10 # number of digits 0-9
n_center = 0  # needed only by RBF
beta = 0 # needed only by RBF

if model_ID ==1:
    model_name = "dense_1L"
elif model_ID ==2:
    model_name = "dense"
elif model_ID==3:
    n_center = 10
    beta = 10
    model_name = "RBF_10center"
elif model_ID==4:
    n_center = 50
    beta = 10
    model_name = "RBF_50center"
elif model_ID==5:
    model_name = "CNN_simple"
elif model_ID==6:
    model_name = "CNN"

#load the mnist data
X_train_raw, Y_train_raw, X_test_raw, Y_test_raw, X_train, Y_train, X_test, Y_test = load_mnist_data(n_classes)

# the model
model = NN_mnist(model_name, n_classes,  X_train, Y_train, X_train_raw, Y_train_raw, X_test, Y_test, n_center, InitCentersKmean, beta)

# train or load the model
if is_training:
    model.run(batch_size, epochs, verbose)
else:
    model.load_model()

model.eval()
# Out:
# C:\Users\wxie\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning: Data with input dtype uint8 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# (60000, 28, 28, 1) (10000, 28, 28, 1) ++++
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/1
# 60000/60000 [==============================] - 6s 97us/step - loss: 0.2622 - acc: 0.9223 - val_loss: 0.0839 - val_acc: 0.9729
# ___ saving the model weight____
# __Loss:   0.07894507128180316
# __Accuracy:  0.9755

# %%
# this is the training sample
model.plot_random_sample(X_train, X_train_raw, Y_train_raw, "incorrect")
# Out:
# ___ calculating the correct and incorrect prediction _____
# __complete___
# __wrongly identified image _____

# %%
# this is the test sample 
model.plot_random_sample(X_test, X_test_raw, Y_test_raw, "correct")
# Out:
# ___ calculating the correct and incorrect prediction _____
# __complete___
# __correctly identified image _____

# %%
# Write the graph in binary .pb file. Convert keras model to a tensorflow model
outdir = "keras_to_TF"
try:
    os.mkdir(outdir )
except:
    pass

prefix = model_name 
name = prefix+'_output_graph.pb' # Alias the outputs in the model - this sometimes makes them easier to access in TF

pred = []
pred_node_names = []
for i, o in enumerate(model.outputs()):
        pred_node_names.append(prefix+'_'+str(i))
        pred.append(tf.identity(o, name=pred_node_names[i]))
print('Output nodes names are: ', pred_node_names[0])

if is_training: # converting keras model to TF model
    sess = K.get_session()
    constant_graph = graph_util.convert_variables_to_constants(sess, 
                                                               sess.graph.as_graph_def(), 
                                                               pred_node_names)
    graph_io.write_graph(constant_graph, outdir, name, as_text=False)
    ## Finally delete the Keras's session
    #K.clear_session() # somehow doesn't work for CNN
    
#load the tensorflow model from the file
#tf.reset_default_graph() # somehow doesn't work for CNN

def load_graph(model_name):
    graph = tf.get_default_graph()
    graph_def = tf.GraphDef()
    with open(model_name, "rb") as f:
        graph_def.ParseFromString(f.read())
    with graph.as_default():
        tf.import_graph_def(graph_def)
    return graph
# Out:
# Output nodes names are:  CNN_0
# INFO:tensorflow:Froze 10 variables.
# Converted 10 variables to const ops.

# %%
# print out the operation name for double check. No need to run if one is sure about the name of the operation
for i, op in enumerate(tf.get_default_graph().get_operations()):
    print ("{: 3.0f}: {}".format(i,op.name))
# Out:
#   0: CNN_input
#   1: CNN/random_uniform/shape
#   2: CNN/random_uniform/min
#   3: CNN/random_uniform/max
#   4: CNN/random_uniform/RandomUniform
#   5: CNN/random_uniform/sub
#   6: CNN/random_uniform/mul
#   7: CNN/random_uniform
#   8: CNN/kernel
#   9: CNN/kernel/Assign
#  10: CNN/kernel/read
#  11: CNN/Const
#  12: CNN/bias
#  13: CNN/bias/Assign
#  14: CNN/bias/read
#  15: CNN/convolution/dilation_rate
#  16: CNN/convolution
#  17: CNN/BiasAdd
#  18: CNN/Relu
#  19: conv2d_1/random_uniform/shape
#  20: conv2d_1/random_uniform/min
#  21: conv2d_1/random_uniform/max
#  22: conv2d_1/random_uniform/RandomUniform
#  23: conv2d_1/random_uniform/sub
#  24: conv2d_1/random_uniform/mul
#  25: conv2d_1/random_uniform
#  26: conv2d_1/kernel
#  27: conv2d_1/kernel/Assign
#  28: conv2d_1/kernel/read
#  29: conv2d_1/Const
#  30: conv2d_1/bias
#  31: conv2d_1/bias/Assign
#  32: conv2d_1/bias/read
#  33: conv2d_1/convolution/dilation_rate
#  34: conv2d_1/convolution
#  35: conv2d_1/BiasAdd
#  36: conv2d_1/Relu
#  37: conv2d_2/random_uniform/shape
#  38: conv2d_2/random_uniform/min
#  39: conv2d_2/random_uniform/max
#  40: conv2d_2/random_uniform/RandomUniform
#  41: conv2d_2/random_uniform/sub
#  42: conv2d_2/random_uniform/mul
#  43: conv2d_2/random_uniform
#  44: conv2d_2/kernel
#  45: conv2d_2/kernel/Assign
#  46: conv2d_2/kernel/read
#  47: conv2d_2/Const
#  48: conv2d_2/bias
#  49: conv2d_2/bias/Assign
#  50: conv2d_2/bias/read
#  51: conv2d_2/convolution/dilation_rate
#  52: conv2d_2/convolution
#  53: conv2d_2/BiasAdd
#  54: conv2d_2/Relu
#  55: flatten_1/Shape
#  56: flatten_1/strided_slice/stack
#  57: flatten_1/strided_slice/stack_1
#  58: flatten_1/strided_slice/stack_2
#  59: flatten_1/strided_slice
#  60: flatten_1/Const
#  61: flatten_1/Prod
#  62: flatten_1/stack/0
#  63: flatten_1/stack
#  64: flatten_1/Reshape
#  65: dense_1/random_uniform/shape
#  66: dense_1/random_uniform/min
#  67: dense_1/random_uniform/max
#  68: dense_1/random_uniform/RandomUniform
#  69: dense_1/random_uniform/sub
#  70: dense_1/random_uniform/mul
#  71: dense_1/random_uniform
#  72: dense_1/kernel
#  73: dense_1/kernel/Assign
#  74: dense_1/kernel/read
#  75: dense_1/Const
#  76: dense_1/bias
#  77: dense_1/bias/Assign
#  78: dense_1/bias/read
#  79: dense_1/MatMul
#  80: dense_1/BiasAdd
#  81: dense_1/Relu
#  82: logits/random_uniform/shape
#  83: logits/random_uniform/min
#  84: logits/random_uniform/max
#  85: logits/random_uniform/RandomUniform
#  86: logits/random_uniform/sub
#  87: logits/random_uniform/mul
#  88: logits/random_uniform
#  89: logits/kernel
#  90: logits/kernel/Assign
#  91: logits/kernel/read
#  92: logits/Const
#  93: logits/bias
#  94: logits/bias/Assign
#  95: logits/bias/read
#  96: logits/MatMul
#  97: logits/BiasAdd
#  98: activation_1/Softmax
#  99: Adam/iterations/initial_value
#  100: Adam/iterations
#  101: Adam/iterations/Assign
#  102: Adam/iterations/read
#  103: Adam/lr/initial_value
#  104: Adam/lr
#  105: Adam/lr/Assign
#  106: Adam/lr/read
#  107: Adam/beta_1/initial_value
#  108: Adam/beta_1
#  109: Adam/beta_1/Assign
#  110: Adam/beta_1/read
#  111: Adam/beta_2/initial_value
#  112: Adam/beta_2
#  113: Adam/beta_2/Assign
#  114: Adam/beta_2/read
#  115: Adam/decay/initial_value
#  116: Adam/decay
#  117: Adam/decay/Assign
#  118: Adam/decay/read
#  119: activation_1_target
#  120: activation_1_sample_weights
#  121: loss/activation_1_loss/Sum/reduction_indices
#  122: loss/activation_1_loss/Sum
#  123: loss/activation_1_loss/truediv
#  124: loss/activation_1_loss/Const
#  125: loss/activation_1_loss/sub/x
#  126: loss/activation_1_loss/sub
#  127: loss/activation_1_loss/clip_by_value
#  128: loss/activation_1_loss/Log
#  129: loss/activation_1_loss/mul
#  130: loss/activation_1_loss/Sum_1/reduction_indices
#  131: loss/activation_1_loss/Sum_1
#  132: loss/activation_1_loss/Neg
#  133: loss/activation_1_loss/Mean/reduction_indices
#  134: loss/activation_1_loss/Mean
#  135: loss/activation_1_loss/mul_1
#  136: loss/activation_1_loss/NotEqual/y
#  137: loss/activation_1_loss/NotEqual
#  138: loss/activation_1_loss/Cast
#  139: loss/activation_1_loss/Const_1
#  140: loss/activation_1_loss/Mean_1
#  141: loss/activation_1_loss/truediv_1
#  142: loss/activation_1_loss/Const_2
#  143: loss/activation_1_loss/Mean_2
#  144: loss/mul/x
#  145: loss/mul
#  146: metrics/acc/ArgMax/dimension
#  147: metrics/acc/ArgMax
#  148: metrics/acc/ArgMax_1/dimension
#  149: metrics/acc/ArgMax_1
#  150: metrics/acc/Equal
#  151: metrics/acc/Cast
#  152: metrics/acc/Const
#  153: metrics/acc/Mean
#  154: training/Adam/gradients/Shape
#  155: training/Adam/gradients/grad_ys_0
#  156: training/Adam/gradients/Fill
#  157: training/Adam/gradients/loss/mul_grad/Mul
#  158: training/Adam/gradients/loss/mul_grad/Mul_1
#  159: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Reshape/shape
#  160: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Reshape
#  161: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Shape
#  162: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Tile
#  163: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Shape_1
#  164: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Shape_2
#  165: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Const
#  166: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Prod
#  167: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Const_1
#  168: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Prod_1
#  169: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Maximum/y
#  170: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Maximum
#  171: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/floordiv
#  172: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/Cast
#  173: training/Adam/gradients/loss/activation_1_loss/Mean_2_grad/truediv
#  174: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Shape
#  175: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Shape_1
#  176: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/BroadcastGradientArgs
#  177: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/RealDiv
#  178: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Sum
#  179: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Reshape
#  180: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Neg
#  181: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/RealDiv_1
#  182: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/RealDiv_2
#  183: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/mul
#  184: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Sum_1
#  185: training/Adam/gradients/loss/activation_1_loss/truediv_1_grad/Reshape_1
#  186: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Shape
#  187: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Shape_1
#  188: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/BroadcastGradientArgs
#  189: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Mul
#  190: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Sum
#  191: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Reshape
#  192: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Mul_1
#  193: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Sum_1
#  194: training/Adam/gradients/loss/activation_1_loss/mul_1_grad/Reshape_1
#  195: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Shape
#  196: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Size
#  197: training/Adam/gradients/loss/activation_1_loss/Mean_grad/add
#  198: training/Adam/gradients/loss/activation_1_loss/Mean_grad/mod
#  199: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Shape_1
#  200: training/Adam/gradients/loss/activation_1_loss/Mean_grad/range/start
#  201: training/Adam/gradients/loss/activation_1_loss/Mean_grad/range/delta
#  202: training/Adam/gradients/loss/activation_1_loss/Mean_grad/range
#  203: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Fill/value
#  204: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Fill
#  205: training/Adam/gradients/loss/activation_1_loss/Mean_grad/DynamicStitch
#  206: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Maximum/y
#  207: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Maximum
#  208: training/Adam/gradients/loss/activation_1_loss/Mean_grad/floordiv
#  209: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Reshape
#  210: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Tile
#  211: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Shape_2
#  212: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Shape_3
#  213: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Const
#  214: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Prod
#  215: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Const_1
#  216: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Prod_1
#  217: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Maximum_1/y
#  218: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Maximum_1
#  219: training/Adam/gradients/loss/activation_1_loss/Mean_grad/floordiv_1
#  220: training/Adam/gradients/loss/activation_1_loss/Mean_grad/Cast
#  221: training/Adam/gradients/loss/activation_1_loss/Mean_grad/truediv
#  222: training/Adam/gradients/loss/activation_1_loss/Neg_grad/Neg
#  223: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Shape
#  224: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Size
#  225: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/add
#  226: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/mod
#  227: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Shape_1
#  228: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/range/start
#  229: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/range/delta
#  230: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/range
#  231: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Fill/value
#  232: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Fill
#  233: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/DynamicStitch
#  234: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Maximum/y
#  235: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Maximum
#  236: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/floordiv
#  237: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Reshape
#  238: training/Adam/gradients/loss/activation_1_loss/Sum_1_grad/Tile
#  239: training/Adam/gradients/loss/activation_1_loss/mul_grad/Shape
#  240: training/Adam/gradients/loss/activation_1_loss/mul_grad/Shape_1
#  241: training/Adam/gradients/loss/activation_1_loss/mul_grad/BroadcastGradientArgs
#  242: training/Adam/gradients/loss/activation_1_loss/mul_grad/Mul
#  243: training/Adam/gradients/loss/activation_1_loss/mul_grad/Sum
#  244: training/Adam/gradients/loss/activation_1_loss/mul_grad/Reshape
#  245: training/Adam/gradients/loss/activation_1_loss/mul_grad/Mul_1
#  246: training/Adam/gradients/loss/activation_1_loss/mul_grad/Sum_1
#  247: training/Adam/gradients/loss/activation_1_loss/mul_grad/Reshape_1
#  248: training/Adam/gradients/loss/activation_1_loss/Log_grad/Reciprocal
#  249: training/Adam/gradients/loss/activation_1_loss/Log_grad/mul
#  250: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Shape
#  251: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Shape_1
#  252: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Shape_2
#  253: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Shape_3
#  254: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/zeros/Const
#  255: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/zeros
#  256: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Less
#  257: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Greater
#  258: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/BroadcastGradientArgs
#  259: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/BroadcastGradientArgs_1
#  260: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/LogicalOr
#  261: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Select
#  262: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Select_1
#  263: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Select_2
#  264: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Sum
#  265: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Reshape
#  266: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Sum_1
#  267: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Reshape_1
#  268: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Sum_2
#  269: training/Adam/gradients/loss/activation_1_loss/clip_by_value_grad/Reshape_2
#  270: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Shape
#  271: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Shape_1
#  272: training/Adam/gradients/loss/activation_1_loss/truediv_grad/BroadcastGradientArgs
#  273: training/Adam/gradients/loss/activation_1_loss/truediv_grad/RealDiv
#  274: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Sum
#  275: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Reshape
#  276: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Neg
#  277: training/Adam/gradients/loss/activation_1_loss/truediv_grad/RealDiv_1
#  278: training/Adam/gradients/loss/activation_1_loss/truediv_grad/RealDiv_2
#  279: training/Adam/gradients/loss/activation_1_loss/truediv_grad/mul
#  280: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Sum_1
#  281: training/Adam/gradients/loss/activation_1_loss/truediv_grad/Reshape_1
#  282: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Shape
#  283: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Size
#  284: training/Adam/gradients/loss/activation_1_loss/Sum_grad/add
#  285: training/Adam/gradients/loss/activation_1_loss/Sum_grad/mod
#  286: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Shape_1
#  287: training/Adam/gradients/loss/activation_1_loss/Sum_grad/range/start
#  288: training/Adam/gradients/loss/activation_1_loss/Sum_grad/range/delta
#  289: training/Adam/gradients/loss/activation_1_loss/Sum_grad/range
#  290: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Fill/value
#  291: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Fill
#  292: training/Adam/gradients/loss/activation_1_loss/Sum_grad/DynamicStitch
#  293: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Maximum/y
#  294: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Maximum
#  295: training/Adam/gradients/loss/activation_1_loss/Sum_grad/floordiv
#  296: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Reshape
#  297: training/Adam/gradients/loss/activation_1_loss/Sum_grad/Tile
#  298: training/Adam/gradients/AddN
#  299: training/Adam/gradients/activation_1/Softmax_grad/mul
#  300: training/Adam/gradients/activation_1/Softmax_grad/Sum/reduction_indices
#  301: training/Adam/gradients/activation_1/Softmax_grad/Sum
#  302: training/Adam/gradients/activation_1/Softmax_grad/Reshape/shape
#  303: training/Adam/gradients/activation_1/Softmax_grad/Reshape
#  304: training/Adam/gradients/activation_1/Softmax_grad/sub
#  305: training/Adam/gradients/activation_1/Softmax_grad/mul_1
#  306: training/Adam/gradients/logits/BiasAdd_grad/BiasAddGrad
#  307: training/Adam/gradients/logits/MatMul_grad/MatMul
#  308: training/Adam/gradients/logits/MatMul_grad/MatMul_1
#  309: training/Adam/gradients/dense_1/Relu_grad/ReluGrad
#  310: training/Adam/gradients/dense_1/BiasAdd_grad/BiasAddGrad
#  311: training/Adam/gradients/dense_1/MatMul_grad/MatMul
#  312: training/Adam/gradients/dense_1/MatMul_grad/MatMul_1
#  313: training/Adam/gradients/flatten_1/Reshape_grad/Shape
#  314: training/Adam/gradients/flatten_1/Reshape_grad/Reshape
#  315: training/Adam/gradients/conv2d_2/Relu_grad/ReluGrad
#  316: training/Adam/gradients/conv2d_2/BiasAdd_grad/BiasAddGrad
#  317: training/Adam/gradients/conv2d_2/convolution_grad/ShapeN
#  318: training/Adam/gradients/conv2d_2/convolution_grad/Const
#  319: training/Adam/gradients/conv2d_2/convolution_grad/Conv2DBackpropInput
#  320: training/Adam/gradients/conv2d_2/convolution_grad/Conv2DBackpropFilter
#  321: training/Adam/gradients/conv2d_1/Relu_grad/ReluGrad
#  322: training/Adam/gradients/conv2d_1/BiasAdd_grad/BiasAddGrad
#  323: training/Adam/gradients/conv2d_1/convolution_grad/ShapeN
#  324: training/Adam/gradients/conv2d_1/convolution_grad/Const
#  325: training/Adam/gradients/conv2d_1/convolution_grad/Conv2DBackpropInput
#  326: training/Adam/gradients/conv2d_1/convolution_grad/Conv2DBackpropFilter
#  327: training/Adam/gradients/CNN/Relu_grad/ReluGrad
#  328: training/Adam/gradients/CNN/BiasAdd_grad/BiasAddGrad
#  329: training/Adam/gradients/CNN/convolution_grad/ShapeN
#  330: training/Adam/gradients/CNN/convolution_grad/Const
#  331: training/Adam/gradients/CNN/convolution_grad/Conv2DBackpropInput
#  332: training/Adam/gradients/CNN/convolution_grad/Conv2DBackpropFilter
#  333: training/Adam/AssignAdd/value
#  334: training/Adam/AssignAdd
#  335: training/Adam/Cast
#  336: training/Adam/add/y
#  337: training/Adam/add
#  338: training/Adam/Pow
#  339: training/Adam/sub/x
#  340: training/Adam/sub
#  341: training/Adam/Const
#  342: training/Adam/Const_1
#  343: training/Adam/clip_by_value
#  344: training/Adam/Sqrt
#  345: training/Adam/Pow_1
#  346: training/Adam/sub_1/x
#  347: training/Adam/sub_1
#  348: training/Adam/truediv
#  349: training/Adam/mul
#  350: training/Adam/zeros
#  351: training/Adam/Variable
#  352: training/Adam/Variable/Assign
#  353: training/Adam/Variable/read
#  354: training/Adam/zeros_1
#  355: training/Adam/Variable_1
#  356: training/Adam/Variable_1/Assign
#  357: training/Adam/Variable_1/read
#  358: training/Adam/zeros_2/shape_as_tensor
#  359: training/Adam/zeros_2/Const
#  360: training/Adam/zeros_2
#  361: training/Adam/Variable_2
#  362: training/Adam/Variable_2/Assign
#  363: training/Adam/Variable_2/read
#  364: training/Adam/zeros_3
#  365: training/Adam/Variable_3
#  366: training/Adam/Variable_3/Assign
#  367: training/Adam/Variable_3/read
#  368: training/Adam/zeros_4/shape_as_tensor
#  369: training/Adam/zeros_4/Const
#  370: training/Adam/zeros_4
#  371: training/Adam/Variable_4
#  372: training/Adam/Variable_4/Assign
#  373: training/Adam/Variable_4/read
#  374: training/Adam/zeros_5
#  375: training/Adam/Variable_5
#  376: training/Adam/Variable_5/Assign
#  377: training/Adam/Variable_5/read
#  378: training/Adam/zeros_6/shape_as_tensor
#  379: training/Adam/zeros_6/Const
#  380: training/Adam/zeros_6
#  381: training/Adam/Variable_6
#  382: training/Adam/Variable_6/Assign
#  383: training/Adam/Variable_6/read
#  384: training/Adam/zeros_7
#  385: training/Adam/Variable_7
#  386: training/Adam/Variable_7/Assign
#  387: training/Adam/Variable_7/read
#  388: training/Adam/zeros_8/shape_as_tensor
#  389: training/Adam/zeros_8/Const
#  390: training/Adam/zeros_8
#  391: training/Adam/Variable_8
#  392: training/Adam/Variable_8/Assign
#  393: training/Adam/Variable_8/read
#  394: training/Adam/zeros_9
#  395: training/Adam/Variable_9
#  396: training/Adam/Variable_9/Assign
#  397: training/Adam/Variable_9/read
#  398: training/Adam/zeros_10
#  399: training/Adam/Variable_10
#  400: training/Adam/Variable_10/Assign
#  401: training/Adam/Variable_10/read
#  402: training/Adam/zeros_11
#  403: training/Adam/Variable_11
#  404: training/Adam/Variable_11/Assign
#  405: training/Adam/Variable_11/read
#  406: training/Adam/zeros_12/shape_as_tensor
#  407: training/Adam/zeros_12/Const
#  408: training/Adam/zeros_12
#  409: training/Adam/Variable_12
#  410: training/Adam/Variable_12/Assign
#  411: training/Adam/Variable_12/read
#  412: training/Adam/zeros_13
#  413: training/Adam/Variable_13
#  414: training/Adam/Variable_13/Assign
#  415: training/Adam/Variable_13/read
#  416: training/Adam/zeros_14/shape_as_tensor
#  417: training/Adam/zeros_14/Const
#  418: training/Adam/zeros_14
#  419: training/Adam/Variable_14
#  420: training/Adam/Variable_14/Assign
#  421: training/Adam/Variable_14/read
#  422: training/Adam/zeros_15
#  423: training/Adam/Variable_15
#  424: training/Adam/Variable_15/Assign
#  425: training/Adam/Variable_15/read
#  426: training/Adam/zeros_16/shape_as_tensor
#  427: training/Adam/zeros_16/Const
#  428: training/Adam/zeros_16
#  429: training/Adam/Variable_16
#  430: training/Adam/Variable_16/Assign
#  431: training/Adam/Variable_16/read
#  432: training/Adam/zeros_17
#  433: training/Adam/Variable_17
#  434: training/Adam/Variable_17/Assign
#  435: training/Adam/Variable_17/read
#  436: training/Adam/zeros_18/shape_as_tensor
#  437: training/Adam/zeros_18/Const
#  438: training/Adam/zeros_18
#  439: training/Adam/Variable_18
#  440: training/Adam/Variable_18/Assign
#  441: training/Adam/Variable_18/read
#  442: training/Adam/zeros_19
#  443: training/Adam/Variable_19
#  444: training/Adam/Variable_19/Assign
#  445: training/Adam/Variable_19/read
#  446: training/Adam/zeros_20/shape_as_tensor
#  447: training/Adam/zeros_20/Const
#  448: training/Adam/zeros_20
#  449: training/Adam/Variable_20
#  450: training/Adam/Variable_20/Assign
#  451: training/Adam/Variable_20/read
#  452: training/Adam/zeros_21/shape_as_tensor
#  453: training/Adam/zeros_21/Const
#  454: training/Adam/zeros_21
#  455: training/Adam/Variable_21
#  456: training/Adam/Variable_21/Assign
#  457: training/Adam/Variable_21/read
#  458: training/Adam/zeros_22/shape_as_tensor
#  459: training/Adam/zeros_22/Const
#  460: training/Adam/zeros_22
#  461: training/Adam/Variable_22
#  462: training/Adam/Variable_22/Assign
#  463: training/Adam/Variable_22/read
#  464: training/Adam/zeros_23/shape_as_tensor
#  465: training/Adam/zeros_23/Const
#  466: training/Adam/zeros_23
#  467: training/Adam/Variable_23
#  468: training/Adam/Variable_23/Assign
#  469: training/Adam/Variable_23/read
#  470: training/Adam/zeros_24/shape_as_tensor
#  471: training/Adam/zeros_24/Const
#  472: training/Adam/zeros_24
#  473: training/Adam/Variable_24
#  474: training/Adam/Variable_24/Assign
#  475: training/Adam/Variable_24/read
#  476: training/Adam/zeros_25/shape_as_tensor
#  477: training/Adam/zeros_25/Const
#  478: training/Adam/zeros_25
#  479: training/Adam/Variable_25
#  480: training/Adam/Variable_25/Assign
#  481: training/Adam/Variable_25/read
#  482: training/Adam/zeros_26/shape_as_tensor
#  483: training/Adam/zeros_26/Const
#  484: training/Adam/zeros_26
#  485: training/Adam/Variable_26
#  486: training/Adam/Variable_26/Assign
#  487: training/Adam/Variable_26/read
#  488: training/Adam/zeros_27/shape_as_tensor
#  489: training/Adam/zeros_27/Const
#  490: training/Adam/zeros_27
#  491: training/Adam/Variable_27
#  492: training/Adam/Variable_27/Assign
#  493: training/Adam/Variable_27/read
#  494: training/Adam/zeros_28/shape_as_tensor
#  495: training/Adam/zeros_28/Const
#  496: training/Adam/zeros_28
#  497: training/Adam/Variable_28
#  498: training/Adam/Variable_28/Assign
#  499: training/Adam/Variable_28/read
#  500: training/Adam/zeros_29/shape_as_tensor
#  501: training/Adam/zeros_29/Const
#  502: training/Adam/zeros_29
#  503: training/Adam/Variable_29
#  504: training/Adam/Variable_29/Assign
#  505: training/Adam/Variable_29/read
#  506: training/Adam/mul_1
#  507: training/Adam/sub_2/x
#  508: training/Adam/sub_2
#  509: training/Adam/mul_2
#  510: training/Adam/add_1
#  511: training/Adam/mul_3
#  512: training/Adam/sub_3/x
#  513: training/Adam/sub_3
#  514: training/Adam/Square
#  515: training/Adam/mul_4
#  516: training/Adam/add_2
#  517: training/Adam/mul_5
#  518: training/Adam/Const_2
#  519: training/Adam/Const_3
#  520: training/Adam/clip_by_value_1
#  521: training/Adam/Sqrt_1
#  522: training/Adam/add_3/y
#  523: training/Adam/add_3
#  524: training/Adam/truediv_1
#  525: training/Adam/sub_4
#  526: training/Adam/Assign
#  527: training/Adam/Assign_1
#  528: training/Adam/Assign_2
#  529: training/Adam/mul_6
#  530: training/Adam/sub_5/x
#  531: training/Adam/sub_5
#  532: training/Adam/mul_7
#  533: training/Adam/add_4
#  534: training/Adam/mul_8
#  535: training/Adam/sub_6/x
#  536: training/Adam/sub_6
#  537: training/Adam/Square_1
#  538: training/Adam/mul_9
#  539: training/Adam/add_5
#  540: training/Adam/mul_10
#  541: training/Adam/Const_4
#  542: training/Adam/Const_5
#  543: training/Adam/clip_by_value_2
#  544: training/Adam/Sqrt_2
#  545: training/Adam/add_6/y
#  546: training/Adam/add_6
#  547: training/Adam/truediv_2
#  548: training/Adam/sub_7
#  549: training/Adam/Assign_3
#  550: training/Adam/Assign_4
#  551: training/Adam/Assign_5
#  552: training/Adam/mul_11
#  553: training/Adam/sub_8/x
#  554: training/Adam/sub_8
#  555: training/Adam/mul_12
#  556: training/Adam/add_7
#  557: training/Adam/mul_13
#  558: training/Adam/sub_9/x
#  559: training/Adam/sub_9
#  560: training/Adam/Square_2
#  561: training/Adam/mul_14
#  562: training/Adam/add_8
#  563: training/Adam/mul_15
#  564: training/Adam/Const_6
#  565: training/Adam/Const_7
#  566: training/Adam/clip_by_value_3
#  567: training/Adam/Sqrt_3
#  568: training/Adam/add_9/y
#  569: training/Adam/add_9
#  570: training/Adam/truediv_3
#  571: training/Adam/sub_10
#  572: training/Adam/Assign_6
#  573: training/Adam/Assign_7
#  574: training/Adam/Assign_8
#  575: training/Adam/mul_16
#  576: training/Adam/sub_11/x
#  577: training/Adam/sub_11
#  578: training/Adam/mul_17
#  579: training/Adam/add_10
#  580: training/Adam/mul_18
#  581: training/Adam/sub_12/x
#  582: training/Adam/sub_12
#  583: training/Adam/Square_3
#  584: training/Adam/mul_19
#  585: training/Adam/add_11
#  586: training/Adam/mul_20
#  587: training/Adam/Const_8
#  588: training/Adam/Const_9
#  589: training/Adam/clip_by_value_4
#  590: training/Adam/Sqrt_4
#  591: training/Adam/add_12/y
#  592: training/Adam/add_12
#  593: training/Adam/truediv_4
#  594: training/Adam/sub_13
#  595: training/Adam/Assign_9
#  596: training/Adam/Assign_10
#  597: training/Adam/Assign_11
#  598: training/Adam/mul_21
#  599: training/Adam/sub_14/x
#  600: training/Adam/sub_14
#  601: training/Adam/mul_22
#  602: training/Adam/add_13
#  603: training/Adam/mul_23
#  604: training/Adam/sub_15/x
#  605: training/Adam/sub_15
#  606: training/Adam/Square_4
#  607: training/Adam/mul_24
#  608: training/Adam/add_14
#  609: training/Adam/mul_25
#  610: training/Adam/Const_10
#  611: training/Adam/Const_11
#  612: training/Adam/clip_by_value_5
#  613: training/Adam/Sqrt_5
#  614: training/Adam/add_15/y
#  615: training/Adam/add_15
#  616: training/Adam/truediv_5
#  617: training/Adam/sub_16
#  618: training/Adam/Assign_12
#  619: training/Adam/Assign_13
#  620: training/Adam/Assign_14
#  621: training/Adam/mul_26
#  622: training/Adam/sub_17/x
#  623: training/Adam/sub_17
#  624: training/Adam/mul_27
#  625: training/Adam/add_16
#  626: training/Adam/mul_28
#  627: training/Adam/sub_18/x
#  628: training/Adam/sub_18
#  629: training/Adam/Square_5
#  630: training/Adam/mul_29
#  631: training/Adam/add_17
#  632: training/Adam/mul_30
#  633: training/Adam/Const_12
#  634: training/Adam/Const_13
#  635: training/Adam/clip_by_value_6
#  636: training/Adam/Sqrt_6
#  637: training/Adam/add_18/y
#  638: training/Adam/add_18
#  639: training/Adam/truediv_6
#  640: training/Adam/sub_19
#  641: training/Adam/Assign_15
#  642: training/Adam/Assign_16
#  643: training/Adam/Assign_17
#  644: training/Adam/mul_31
#  645: training/Adam/sub_20/x
#  646: training/Adam/sub_20
#  647: training/Adam/mul_32
#  648: training/Adam/add_19
#  649: training/Adam/mul_33
#  650: training/Adam/sub_21/x
#  651: training/Adam/sub_21
#  652: training/Adam/Square_6
#  653: training/Adam/mul_34
#  654: training/Adam/add_20
#  655: training/Adam/mul_35
#  656: training/Adam/Const_14
#  657: training/Adam/Const_15
#  658: training/Adam/clip_by_value_7
#  659: training/Adam/Sqrt_7
#  660: training/Adam/add_21/y
#  661: training/Adam/add_21
#  662: training/Adam/truediv_7
#  663: training/Adam/sub_22
#  664: training/Adam/Assign_18
#  665: training/Adam/Assign_19
#  666: training/Adam/Assign_20
#  667: training/Adam/mul_36
#  668: training/Adam/sub_23/x
#  669: training/Adam/sub_23
#  670: training/Adam/mul_37
#  671: training/Adam/add_22
#  672: training/Adam/mul_38
#  673: training/Adam/sub_24/x
#  674: training/Adam/sub_24
#  675: training/Adam/Square_7
#  676: training/Adam/mul_39
#  677: training/Adam/add_23
#  678: training/Adam/mul_40
#  679: training/Adam/Const_16
#  680: training/Adam/Const_17
#  681: training/Adam/clip_by_value_8
#  682: training/Adam/Sqrt_8
#  683: training/Adam/add_24/y
#  684: training/Adam/add_24
#  685: training/Adam/truediv_8
#  686: training/Adam/sub_25
#  687: training/Adam/Assign_21
#  688: training/Adam/Assign_22
#  689: training/Adam/Assign_23
#  690: training/Adam/mul_41
#  691: training/Adam/sub_26/x
#  692: training/Adam/sub_26
#  693: training/Adam/mul_42
#  694: training/Adam/add_25
#  695: training/Adam/mul_43
#  696: training/Adam/sub_27/x
#  697: training/Adam/sub_27
#  698: training/Adam/Square_8
#  699: training/Adam/mul_44
#  700: training/Adam/add_26
#  701: training/Adam/mul_45
#  702: training/Adam/Const_18
#  703: training/Adam/Const_19
#  704: training/Adam/clip_by_value_9
#  705: training/Adam/Sqrt_9
#  706: training/Adam/add_27/y
#  707: training/Adam/add_27
#  708: training/Adam/truediv_9
#  709: training/Adam/sub_28
#  710: training/Adam/Assign_24
#  711: training/Adam/Assign_25
#  712: training/Adam/Assign_26
#  713: training/Adam/mul_46
#  714: training/Adam/sub_29/x
#  715: training/Adam/sub_29
#  716: training/Adam/mul_47
#  717: training/Adam/add_28
#  718: training/Adam/mul_48
#  719: training/Adam/sub_30/x
#  720: training/Adam/sub_30
#  721: training/Adam/Square_9
#  722: training/Adam/mul_49
#  723: training/Adam/add_29
#  724: training/Adam/mul_50
#  725: training/Adam/Const_20
#  726: training/Adam/Const_21
#  727: training/Adam/clip_by_value_10
#  728: training/Adam/Sqrt_10
#  729: training/Adam/add_30/y
#  730: training/Adam/add_30
#  731: training/Adam/truediv_10
#  732: training/Adam/sub_31
#  733: training/Adam/Assign_27
#  734: training/Adam/Assign_28
#  735: training/Adam/Assign_29
#  736: training/group_deps
#  737: group_deps
#  738: IsVariableInitialized
#  739: IsVariableInitialized_1
#  740: IsVariableInitialized_2
#  741: IsVariableInitialized_3
#  742: IsVariableInitialized_4
#  743: IsVariableInitialized_5
#  744: IsVariableInitialized_6
#  745: IsVariableInitialized_7
#  746: IsVariableInitialized_8
#  747: IsVariableInitialized_9
#  748: IsVariableInitialized_10
#  749: IsVariableInitialized_11
#  750: IsVariableInitialized_12
#  751: IsVariableInitialized_13
#  752: IsVariableInitialized_14
#  753: IsVariableInitialized_15
#  754: IsVariableInitialized_16
#  755: IsVariableInitialized_17
#  756: IsVariableInitialized_18
#  757: IsVariableInitialized_19
#  758: IsVariableInitialized_20
#  759: IsVariableInitialized_21
#  760: IsVariableInitialized_22
#  761: IsVariableInitialized_23
#  762: IsVariableInitialized_24
#  763: IsVariableInitialized_25
#  764: IsVariableInitialized_26
#  765: IsVariableInitialized_27
#  766: IsVariableInitialized_28
#  767: IsVariableInitialized_29
#  768: IsVariableInitialized_30
#  769: IsVariableInitialized_31
#  770: IsVariableInitialized_32
#  771: IsVariableInitialized_33
#  772: IsVariableInitialized_34
#  773: IsVariableInitialized_35
#  774: IsVariableInitialized_36
#  775: IsVariableInitialized_37
#  776: IsVariableInitialized_38
#  777: IsVariableInitialized_39
#  778: IsVariableInitialized_40
#  779: IsVariableInitialized_41
#  780: IsVariableInitialized_42
#  781: IsVariableInitialized_43
#  782: IsVariableInitialized_44
#  783: init
#  784: group_deps_1
#  785: CNN_0

# %%
# the tensorflow model. All one needs are input and output operation and logits operation.  
# load the model
my_graph = load_graph(model_name=os.path.join(outdir, name))

# note: need to add "import" in the option name, otherwise, the keras model and TF model outputs are different
input_op = my_graph.get_operation_by_name("import/"+model_name+"_input") # name of input operation 
output_op = my_graph.get_operation_by_name("import/"+pred_node_names[0]) # name of output operation
logit_op = my_graph.get_operation_by_name("import/logits/BiasAdd") # name of logits operation. Double checked from keras model output

ops = (input_op,output_op, logit_op)

print(input_op.outputs[0].shape)
print(output_op.outputs[0].shape)
# Out:
# (?, 28, 28, 1)
# (?, 10)

# %%
# generate adversarial image  
class AdversarialImage(object):
    def __init__(self, inp, out, logits, name):
        '''
        inp : input tensor  (image)
        out : output tensor (y_pred)
        eps : scalar
        '''
        self.inp = inp.outputs[0] # input tensor
        self.out = out.outputs[0] # output tensor
        self.logits = logits.outputs[0] # logits tensor
        self.name = name # name of the saved file. 
    
    ## cnn need inputs (nsample, color, x_pixel, y_pixel), dense net need inputs: (nsample, x_pixel, y_pixel)
    def reshape_inputs(self, X):
        if "CNN" in self.name: # CNN need 4-D array inputs
            if X.ndim == 1:  # single image
                X = X.reshape(1, 28, 28, 1).astype('float32') # cnn need inputs (nsample, x_pixel, y_pixel, color)
            elif X.ndim==2: 
                X = X.reshape(X.shape[0], 28, 28, 1).astype('float32')
        else:  # dense net need 2-D inputs
            if X.ndim == 1: # single image
                #X = X.reshape(1, X.shape[0]).astype('float32')  # dense net need inputs: (nsample, x_pixel*y_pixel)
                X = X.reshape(1, X.shape[0])  # dense net need inputs: (nsample, x_pixel*y_pixel)

        return X
    

    # obtain adversarial image
    def get_adv_image(self, image, goal_class, nsteps, eps=1, beta = 0.01, verbose=0):
        """
        image: original image 
        goal_class:  the goal class of the adversarial prediction from 0-9 
        nsteps: number of steps to perform gradient descent
        eps: learning rate 
        beta: learning rate for the 2nd term in the loss
        verbose: 0: loss, 1: prob, logistic, loss
        
        """
        image = self.reshape_inputs(image) # make sure the dim is (nsample, image)
        org_image = image # for the 2nd term of the loss 
        
        y_goal_tf = tf.expand_dims(tf.one_hot(goal_class, n_classes), axis=0) # the expansion take care of the nsample dimension
        y_pred_tf = self.logits 

        #adv_image = self.inp - eps*grad_tf # adversarial image tensor going along the gradient direction    
        org_image_tf = tf.placeholder(tf.float32, shape=image.shape)
        
        # this loss is a lot more effective than MSE loss function
        loss = tf.nn.softmax_cross_entropy_with_logits_v2(logits=y_pred_tf, labels=[y_goal_tf])
        grad_tf  = tf.gradients(loss, self.inp)[0] # gradients of loss w.r.t. the image

        #adv_image = tf.zeros(image.shape)
        adv_image = self.inp
        noise_image = tf.zeros(image.shape) # noise added on to the original image
        
        noise_per_step = eps*(grad_tf + beta*(adv_image - org_image_tf))
        
        adv_image -= noise_per_step   # adversarial image tensor going along the gradient direction        
        noise_image += noise_per_step
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())

            # gradient descent
            for i in range(nsteps):
                # need to update image everytime
                adv, noise, vloss, lg, grad, = sess.run([adv_image, noise_image, loss, y_pred_tf,  grad_tf ], 
                                                        feed_dict={self.inp:image, org_image_tf:org_image})
                image = adv # update image every step. the updated image is fed to the self.inp
                
                if verbose != 0:
                    print("loss: ", vloss)
                    print("grad: ", grad[0][0:10])
                    print("logitis:", lg)

                if(i%200 == 0):
                    print("loss: ", vloss)
                 
        return adv, noise # numpy arrage of image
    
    # model prediction of the input image X. can be the original or the adv_image
    def predict(self, image):
        """
        image: input image
        
        """
        image = self.reshape_inputs(image) # check to make the input image shape is (nsample, image)
        
        with tf.Session() as sess:
            sess.run(tf.global_variables_initializer())
            logits, probs = sess.run([self.out, self.logits], feed_dict={self.inp:image})
            
        return probs, logits

    # draw input image together with the probability of the image
    def plot(self, input_images, correct_class, goal_class, figsize=(22, 3)):
        """
        input_images[0]:--> orignial image
        input_images[1]:--> adversarial image
        input_images[2]:--> added noise, i.e. adv_image - org_image
        correct_class:--> correct label
        goal_class:--> goal label for adversarial 
    
        """
        num_of_image = len(input_images)
        probs = np.ndarray(shape=(num_of_image, 1, n_classes)) # define an array
        for i in range(num_of_image):
            input_images[i] = self.reshape_inputs(input_images[i]) # check to make the input image shape is (nsample, image)
            _, probs[i] = self.predict(input_images[i]) # probs[i].shape = (1, 10)      
            
        # subplots with nrow rows and ncoll columns
        nrow = 1
        ncoll = 6
        fig, axes = plt.subplots(nrow, ncoll, figsize=figsize)
        
        ith = 0 # index of input_images[]
        for i in range(0, ncoll, 2):  # remove ticks on axes of images
            axes[i].set_xticks([])
            axes[i].set_yticks([])
            axes[i].imshow(input_images[ith].reshape(X_train_raw[0].shape), cmap='gray', interpolation='none')
            ith += 1
            
        ith = 0 # index of probs[]
        for i in range(1, ncoll, 2):  
            barlist = axes[i].bar(range(n_classes), probs[ith][0]) # draw bar in the plot
            ith +=1  

            barlist[goal_class].set_color('r')
            barlist[correct_class].set_color('g')
            
            axes[i].set_ylim([0, 1.1])
            axes[i].set_ylabel('Probility')
            axes[i].set_xticks(range(n_classes))
            axes[i].set_xticklabels(str(i) for i in range(n_classes))

# %%
adv = AdversarialImage(*ops, name)

# %%
# test if the tensorflow model has the same output as the keras model
X = X_train[0]
a, b = model(X)
print(a)
print(b)

c, d = adv.predict(X)
print(c)
print(d)
# Out:
# [[ -3.2900863  -2.3546538  -1.3365712   7.2671475 -10.421347   10.778597
#    -2.0625124  -3.2337084   1.6413835  -1.2346278]]
# [[7.5373725e-07 1.9207598e-06 5.3164431e-06 2.8984683e-02 6.0277211e-10
#   9.7089356e-01 2.5724605e-06 7.9745234e-07 1.0445522e-04 5.8870060e-06]]
# [[ -3.2900863  -2.3546538  -1.3365712   7.2671475 -10.421347   10.778597
#    -2.0625124  -3.2337084   1.6413835  -1.2346278]]
# [[7.5373725e-07 1.9207598e-06 5.3164431e-06 2.8984683e-02 6.0277211e-10
#   9.7089356e-01 2.5724605e-06 7.9745234e-07 1.0445522e-04 5.8870060e-06]]

# %%
ith = 3  # ith sample in the data
goal_class = 1
nstep = 2000
epsilon = 1
beta = 0.0001

org_image = X_test[ith]
correct_class = Y_test_raw[ith]

adv_image, noise_image = adv.get_adv_image(org_image, goal_class, nstep, epsilon, beta)
# Out:
# loss:  [15.092423]
# loss:  [0.00766065]
# loss:  [0.00431915]
# loss:  [0.0032098]
# loss:  [0.00262904]
# loss:  [0.00227823]
# loss:  [0.00205032]
# loss:  [0.0018878]
# loss:  [0.00177417]
# loss:  [0.00169075]

# %%
input_images = [org_image, adv_image, noise_image]

adv.plot(input_images, correct_class, goal_class)
